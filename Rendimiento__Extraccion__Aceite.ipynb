# %% [markdown]
# <a href="https://colab.research.google.com/github/jesusbuiles/Notebooks_Agro_2026_1/blob/main/Rendimiento__Extraccion__Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L.(r)
#
# $$pa  = lt * 0.92$$
# $$r = (pa/pr)*100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de produccion (Tipo string)
# 2 Solicitar el peso de los racimos en kg (Tipo float).(pr)
# 3 Solicitar los litros de aceite obtenidos (Tipo float).(lt)
nombre= input("Ingrese el nombre del lote: ")
pr= float(input("Ingrese el peso de los racimos en kg: "))
lt= float(input("Ingrese los litros de aceite obtenidos: "))

# PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
pa= lt*0.92
r= (pa/pr)*100

# SALIDA: Informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese los litros de aceite obtenidos: 200
# El rendimiento del lote perico es del 18.4 %

# %% [markdown]
# ```markdown
# Aquí está la explicación de cada línea de código del problema 'Control de Rendimiento en Extracción de Aceite':
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de produccion (Tipo string)
# # 2 Solicitar el peso de los racimos en kg (Tipo float).(pr)
# # 3 Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# ```
# Estas líneas son comentarios que describen las siguientes tres líneas de código, indicando que se solicitará información al usuario.
#
# ```python
# nombre= input("Ingrese el nombre del lote: ")
# ```
# Esta línea pide al usuario que ingrese el nombre del lote de producción. La función `input()` lee la entrada del usuario como una cadena de texto (string), la cual se almacena en la variable `nombre`.
#
# ```python
# pr= float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Esta línea solicita al usuario el peso de los racimos en kilogramos. La función `input()` lee la entrada como texto y luego `float()` convierte ese texto a un número de punto flotante (float), que permite valores decimales. El resultado se guarda en la variable `pr` (peso de los racimos).
#
# ```python
# lt= float(input("Ingrese los litros de aceite obtenidos: "))
# ```
# Similar a la línea anterior, esta solicita los litros de aceite obtenidos. La entrada del usuario se convierte a un número flotante usando `float()` y se almacena en la variable `lt` (litros de aceite).
#
# ```python
# # PROCESO: calcular peso del aceite (pa) y el rendimiento (r)
# ```
# Este es un comentario que indica que las siguientes líneas realizarán los cálculos necesarios.
#
# ```python
# pa= lt*0.92
# ```
# Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite (`lt`) por la densidad del aceite (0.92 kg/L) para obtener el peso total del aceite en kilogramos.
#
# ```python
# r= (pa/pr)*100
# ```
# Esta línea calcula el rendimiento (`r`). Divide el peso del aceite (`pa`) por el peso de los racimos (`pr`) y multiplica el resultado por 100 para obtener un porcentaje. Esto representa el Índice de Rendimiento de Extracción (IRE).
#
# ```python
# # SALIDA: Informar el rendimiento del lote
# ```
# Este comentario indica que la siguiente línea mostrará el resultado al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# Esta línea imprime el resultado final. Muestra un mensaje concatenando varias partes: el texto "El rendimiento del lote", el nombre del lote ingresado por el usuario (`nombre`), el texto "es del", el valor calculado del rendimiento (`r`), y finalmente el símbolo de porcentaje "%".
# ```
